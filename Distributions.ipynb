# %% [markdown]
# ## Explain the use and purpose of at least five “Distributions” functions.
#
# ## Distributions
# There are many distribution curves, each of these distributions has a specific application and use that is appropriate to a particular setting. Some are the well known like the Normal Distribution.

# %%
#import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# There are six variations of the default theme, called deep, muted, pastel, bright, dark, and colorblind.
sns.set( palette="bright", color_codes=True)

# %% [markdown]
# ### 1. np.random.uniform
#
# Generates numbers for uniform distributions
#
# ### What is a Uniform Distribution?
#
# A uniform distribution, sometimes also known as a rectangular distribution, is a distribution that has constant probability. The mean and the median coincide.

# %%
# Let's use some descriptive statistics to check the mean and the median of np.random.uniform data
df = np.random.uniform(1,10,1000)
print("Mean = ", np.mean(df))
print("Median = ",np.median(df))
# Out:
# Mean =  5.416842868733241
# Median =  5.469236546924906

# %%
# Uniform Distributions are rectangular in shape
s = np.random.uniform(1,10,1000)
plt.title("Uniform Distribution Histogram")


sns.distplot(s)
plt.show()

# %%
num_of_points = 80
# loc=0.0 (Mean (“centre”) of the distribution.), scale=1.0 (Standard deviation (spread or “width”) of the distribution.), size=None
uniform_array_1 = np.random.uniform(1, 1, num_of_points)
uniform_array_2 = np.random.uniform(1, 6, num_of_points)
uniform_array_3 = np.random.uniform(1, 9, num_of_points)

test = sns.scatterplot(uniform_array_1, uniform_array_2, uniform_array_3)


plt.show(test)

# %% [markdown]
# ### 2. np.random.binomial
#
# Draw samples from a binomial distribution.
#
# ### What is a Binomial Distribution?
#
# Binomial distribution is used to understand the probability of a particular outcome in repeated independent trials. The probability of a trial is either success or failure. The trials are independent as the outcome or the previous trial had no effect on the next trial, as happens in tossing of coins.

# %%
# number of trials, probability of each trial, no.of times testeed

# 10 trials, probability = 0.1, tested 100
s = np.random.binomial(10, 0.1, 100)


# 5 trials, probability = 0.5, tested 100
b = np.random.binomial(5, 0.5, 100)

sns.distplot(s)
sns.distplot(b)

plt.title('Binomial Distribution')

plt.show()

# %% [markdown]
# ### 3. np.random.normal
# Draw samples from a Normal Distribution
#
# ### What is a Normal Distribution?
#
#
# Data can be "distributed" (spread out) in different ways. But there are many cases where the data tends to be around a central value with no bias left or right, and it gets close to a "Normal Distribution" AKA the Bell curve. The normal distributions occurs often in nature. For example, it describes the commonly occurring distribution of samples influenced by a large number of tiny, random disturbances, each with its own unique distribution.  Heights, blood pressure, measurement error, and IQ scores follow the normal distribution
#
# In a normal distribution:
# - the mean = median = mode
# - symmetry about the centre
# - 50% right and 50% left of the mean

# %%
# np.random.normal(mean, Standard deviation (spread or “width”) of the distribution, Output shape)
p = np.random.normal(10, 0.1, 1000)
s = np.random.normal(10, 0.12, 1000)
q = np.random.normal(10, 0.16, 1000)

sns.distplot(p)
sns.distplot(s)
sns.distplot(q)

plt.title('Normal Distribution')

plt.show()

# %% [markdown]
# ### 4. np.random.triangular
#
# Draw samples from the triangular distribution over the interval [left, right]
#
# ### What is the Triangular Distribution?
# The triangular distribution is a continuous probability distribution with lower limit a, upper limit b and mode c, where a < b and a ≤ c ≤ b.
#
# Triangular distribution is used for when you have no idea what the distribution is but you have some idea what the minimum value is for the variable, the maximum value for the variable and what you think the most likely value is.

# %%
# np.random.triangular(Lower limit, mode, upper limit)
z = np.random.triangular(-20, 10, 80, 100000)

s = np.random.triangular(100, 120, 200, 1000)


sns.distplot(z)
sns.distplot(s)

plt.title('Triangular Distribution')

plt.show()

# %% [markdown]
# ####  Every day use:
#
# A shop uses a triangular distribution to model the future weekly sales. They estimate that the minimum weekly sales is 1000 Eur and the max is 6000 EUR.
#
# They also estimate that the most likely outcome is around 3000 EUR.
#
# So they use a=1000 EUR, b=6000 EUR  and c=3000 EUR.
#
# The graph of the probability density function reaches its maximum of 0.0004 at c=3000 EUR.

# %%
# a=$1000, b=$6000 and c=$3000
sales = np.random.triangular(1000, 3000, 6000, 100000)


sns.distplot(sales)

#label + title
plt.xlabel("Sales Amount")
plt.ylabel("Density")
plt.title('Estimated Weekly sales')

plt.show()

# %% [markdown]
# ### 5. numpy.random.chisquare
#
# Draw samples from a chi-square distribution
#
# ### What is a Chisquare Distribution?
#
# The chi-squared distribution (also chi-square or χ2-distribution) with k degrees of freedom is the distribution of a sum of the squares of k independent standard normal random variables. The chi-square distribution is a special case of the gamma distribution and is one of the most widely used probability distributions in inferential statistics, notably in hypothesis testing or in construction of confidence intervals. When it is being distinguished from the more general noncentral chi-squared distribution, this distribution is sometimes called the central chi-squared distribution.

# %%
p = np.random.chisquare(2,4)

z = np.random.chisquare(8,4)

sns.distplot(p)
sns.distplot(z)

plt.title('Chisquare Distribution')

plt.show()

# %% [markdown]
# # References
#
# http://mathworld.wolfram.com/UniformDistribution.html
#
# https://blog.palisade.com/2008/12/23/uses-of-the-uniform-continuous-distribution/
#
#
# https://en.wikipedia.org/wiki/Normal_distribution
#
# http://muthu.co/understanding-binomial-distribution-using-python/
#
# https://www.mathsisfun.com/data/standard-normal-distribution.html
#
# https://www.researchgate.net/post/Why_triangular_distributions_are_used_as_inputs_for_Monte_Carlo_Simulation
#
# https://learnandteachstatistics.files.wordpress.com/2013/07/notes-on-triangle-distributions.pdf
#
# https://en.wikipedia.org/wiki/Chi-squared_distribution
#
# https://study.com/academy/lesson/chi-square-distribution-definition-examples.html

# %% [markdown]
# ![My Title](simple.png)
