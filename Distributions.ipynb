# %% [markdown]
# # Distributions
# There are many ditribution curves, each of these distributions has a specific application and use that is appropriate to a particular setting. Some are the well known like the Normal Distribution.

# %%
#import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# A uniform distribution, sometimes also known as a rectangular distribution, is a distribution that has constant probability. The mean and the median coincide.

# %%
# Let's use some descriptive statistics to check the mean and the median.
df = np.random.uniform(1,10,1000)
print("Mean = ", np.mean(df))
print("Median = ",np.median(df))
# Out:
# Mean =  5.573825654960489
# Median =  5.584326048970844

# %%
# Uniform Distributions are rectangular in shape
s = np.random.uniform(1,10,1000)
plt.title("Uniform Distribution Histogram")
sns.distplot(s)
plt.show()

# %%
num_of_points = 150

uniform_array_1 = np.random.uniform(0, 1, num_of_points)
uniform_array_2 = np.random.uniform(2, 4, num_of_points)
uniform_array_3 = np.random.uniform(6, 10, num_of_points)

test = sns.scatterplot(uniform_array_1, uniform_array_2)

plt.show(test)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Load the example iris dataset
diamonds = sns.load_dataset("diamonds")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
s = sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)
plt.show(s)

# %%
uniform_array_2 = np.random.uniform(2, 4, num_of_points)
uniform_array_2
# Out:
# array([3.6141132 , 3.36118296, 3.37426912, 3.40792697, 2.64212189,
#        3.61401871, 3.11476952, 2.32669229, 3.00916812, 3.6891152 ,
#        2.79018692, 2.64506914, 2.74145244, 2.30260748, 2.24699058,
#        3.39377826, 2.85213357, 3.26721352, 2.78072962, 2.29116259,
#        2.40242776, 2.98068098, 2.2059676 , 2.99757233, 2.32325009,
#        3.21746323, 3.1186107 , 2.17888292, 3.5747823 , 2.7295064 ,
#        3.87659637, 3.89908015, 3.63199564, 3.6525131 , 2.04844533,
#        3.05515626, 3.0534758 , 2.56101768, 3.73243753, 3.93152046,
#        3.05322751, 3.55153481, 2.40617282, 3.81408762, 3.16167139,
#        2.17869034, 2.7753153 , 3.08590648, 3.57025609, 3.98264625,
#        2.15709944, 2.76068501, 3.26248349, 2.21170253, 3.54088787,
#        3.58802156, 3.91165179, 2.76150829, 2.29294138, 3.23639637,
#        2.38623539, 3.9020075 , 3.50252919, 3.30983204, 3.07194278,
#        2.94922581, 2.96600993, 2.09489637, 2.05346056, 2.15982389,
#        2.75912697, 2.65980451, 2.69589943, 3.36306874, 3.2684572 ,
#        2.91487474, 3.00427429, 3.95112994, 3.13487984, 2.70410319,
#        3.8700329 , 2.64308409, 3.8465916 , 3.01252874, 2.05097247,
#        2.67403278, 2.73399908, 2.33624682, 2.00697439, 3.60292738,
#        3.05134082, 3.84485655, 3.98863823, 3.53166058, 2.51883522,
#        2.14797835, 2.30932611, 2.89061965, 3.32196757, 3.90002131,
#        2.31048721, 3.06948793, 2.23245352, 2.94887816, 3.402668  ,
#        2.01849465, 2.23928946, 3.21872772, 2.93277667, 2.06372052,
#        3.85674698, 2.55012788, 2.12014333, 2.28987237, 2.83476   ,
#        3.09106607, 3.14227256, 2.20830045, 3.15068049, 3.78468235,
#        3.34342036, 2.90002109, 3.10798705, 2.91464688, 3.25148246,
#        3.51475232, 3.12838425, 2.6651262 , 2.08445866, 2.2852419 ,
#        2.18382673, 2.95985314, 2.45035544, 3.59664867, 2.73182278,
#        3.03865816, 2.62419964, 3.12629837, 2.25283424, 2.42017078,
#        3.08784276, 3.0882244 , 3.26500672, 3.36546574, 3.88698504,
#        3.1481947 , 2.76384821, 2.62645865, 3.95539898, 2.9738242 ])

# %% [markdown]
# ## Multinomial Distribution

# %%
s = np.random.multinomial(20, [1/6.]*6, size=1)
sns.distplot(s)
plt.show()

# %% [markdown]
# ## Normal Distribution
#
#
# Data can be "distributed" (spread out) in different ways. But there are many cases where the data tends to be around a central value with no bias left or right, and it gets close to a "Normal Distribution" AKA the Bell curve.
#
# In a normal distribution:
# - the mean = median = mode
# - symmetry about the centre
# - 50% right and 50% left of the mean

# %%
p = np.random.normal(10, 0.1, 1000)
sns.distplot(p)
plt.show()

# %% [markdown]
# # References
#
# http://mathworld.wolfram.com/UniformDistribution.html
#
# https://en.wikipedia.org/wiki/Normal_distribution
#
# https://www.mathsisfun.com/data/standard-normal-distribution.html
